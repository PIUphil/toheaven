# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm

path = '/Windows/Fonts/Hancom Gothic Regular.ttf'
font_name = fm.FontProperties(fname=path, size=50).get_name()
#print(font_name)
plt.rc('font', family=font_name)

# %matplotlib inline

mpl.rcParams['axes.unicode_minus'] = False

file_path = 'C:/fire/소방청_연간화재통계_20191231n.csv'
fire = pd.read_csv(file_path, sep=',', encoding='euc-kr')

count = fire['발화열원대분류'].value_counts()

labels, sizes = list(), list()
for quz, val in count.items():
    labels.append(quz)
    sizes.append(val)
    
colors = ['yellowgreen', 'gold', 'r', 'lightcoral', "green", "blue", "violet", "lightskyblue"]
explode = (0, 0, 0.3, 0, 0, 0, 0, 0)
wedgeprops={'width': 1.5, 'edgecolor': 'w', 'linewidth': 2}

plt.title('화재 주요원인')
plt.pie(sizes, labels=labels, colors=colors, explode=explode, 
        startangle = 150, autopct='%1.1f%%', wedgeprops=wedgeprops, radius=2.5)

mpl.rcParams['font.size'] = 12

plt.legend(loc='upper left', prop={'size': 10})
plt.axis('equal')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm
import random

path = '/Windows/Fonts/Hancom Gothic Regular.ttf'
font_name = fm.FontProperties(fname=path, size=50).get_name()
#print(font_name)
plt.rc('font', family=font_name)

# %matplotlib inline

mpl.rcParams['axes.unicode_minus'] = False

file_path = 'C:/fire/소방청_전국 취약계층 주택용 소방시설 보급 현황_20181231.csv'
sohwa = pd.read_csv(file_path, sep=',', encoding='euc-kr')

count = sohwa['보급률'].values()
# 구분, 보급률


labels, sizes = dict(), list()
for quz, val in count.items():
    labels.append(quz)
    sizes.append(val)
    
colors = ['yellowgreen', 'gold', 'r', 'lightcoral', "green", "blue", "violet", "lightskyblue"]
explode = (0, 0, 0.3, 0, 0, 0, 0, 0)
wedgeprops={'width': 1.5, 'edgecolor': 'w', 'linewidth': 2}

plt.title('화재 주요원인')
plt.pie(sizes, labels=labels, colors=colors, explode=explode, 
        startangle = 150, autopct='%1.1f%%', wedgeprops=wedgeprops, radius=2.5)

mpl.rcParams['font.size'] = 12

plt.legend(loc='upper left', prop={'size': 10})
plt.axis('equal')
plt.show()

# %%
path = '/Windows/Fonts/Hancom Gothic Regular.ttf'
font_name = fm.FontProperties(fname=path, size=50).get_name()
#print(font_name)
plt.rc('font', family=font_name)

# %matplotlib inline

mpl.rcParams['axes.unicode_minus'] = False

file_path = 'C:/fire/소방청_전국 취약계층 주택용 소방시설 보급 현황_20181231.csv'
sohwa = pd.read_csv(file_path, sep=',', encoding='euc-kr')

a = sohwa['구분']; b = sohwa['보급률']
dic_bog = {}
labels, sizes = list(), list()

for i in range(len(a)): dic_bog[a[i]]=b[i]

for region, num in dic_bog:
    labels.append(region)
    sizes.append(num)
    

colors = []; num = 17

for _ in range(num): colors.append("")
for i in range(3*num):
    colors[i//3]+=str(hex(random.randint(1,256)))[-2:]
for j in range(len(colors)): colors[j] = int("#"+colors[j])

#explode = (0, 0, 0.3, 0, 0, 0, 0, 0)
#wedgeprops={'width': 1.5, 'edgecolor': 'w', 'linewidth': 2}

plt.title('화재 주요원인')
plt.pie(sizes, labels=labels, colors=colors)

#mpl.rcParams['font.size'] = 12

plt.legend(loc='upper left', prop={'size': 10})
plt.axis('equal')
plt.show()
# Out:
# --------------------------------------------------------------------------
# ValueError                               Traceback (most recent call last)
# <ipython-input-71-d173459c305d> in <module>
#      28     aa = str(hex(random.randint(1,256)))[-2:]
#      29     colors[i//3]+=aa
# ---> 30 for j in range(len(colors)): colors[j] = int("#"+colors[j])
#      31
#      32 #explode = (0, 0, 0.3, 0, 0, 0, 0, 0)
#
# ValueError: invalid literal for int() with base 10: '#b914f7'

# %%
import random
b = []; num = 17

for _ in range(num): b.append("")
for i in range(3*num):
    a = str(hex(random.randint(1,256)))[-2:]
    b[i//3]+=a
for j in range(len(b)): b[j] = "#"+b[j]

#print(b); print(type(b))
# Out:
# ['#fa9165', '#a4d04e', '#8971x6', '#3df9d0', '#d444aa', '#d1d4dd', '#b8444b', '#e47524', '#67e4f1', '#8159e7', '#568c12', '#618381', '#0051de', '#eb5c56', '#8cf02f', '#c795b6', '#a1bfd8']
# <class 'list'>
