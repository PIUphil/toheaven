# %%
# %matplotlib inline

# 필요한 라이브러리 로딩
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 메모장으로 열어보면 오른쪽아래에 데이터형식이 ANSI로 되어있음
# utf-8로 인코딩해도 에러생김 (UnicodeDecodeError)

# %%
# 데이터 로딩
crime = pd.read_csv('D:/python3/data/crime_in_Seoul.csv', encoding='euc-kr')
crime.head()
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생 절도 검거  폭력 발생  폭력 검거
# 0   중부서      2      2      3      2    105     65  1,395   477  1,355  1,170
# 1   종로서      3      3      6      5    115     98  1,070   413  1,278  1,070
# 2  남대문서      1      0      6      4     65     46  1,153   382    869    794
# 3  서대문서      2      2      5      4    154    124  1,812   738  2,056  1,711
# 4   혜화서      3      2      5      4     96     63  1,114   424  1,015    861

# %%
# 데이터 확인
crime.shape
# Out:
# (31, 11)

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
# 관서명      31 non-null object
# 살인 발생    31 non-null int64
# 살인 검거    31 non-null int64
# 강도 발생    31 non-null int64
# 강도 검거    31 non-null int64
# 강간 발생    31 non-null int64
# 강간 검거    31 non-null int64
# 절도 발생    31 non-null object
# 절도 검거    31 non-null object
# 폭력 발생    31 non-null object
# 폭력 검거    31 non-null object
# dtypes: int64(6), object(5)
# memory usage: 2.7+ KB

# %%
crime.columns
# Out:
# Index(['관서명', '살인 발생', '살인 검거', '강도 발생', '강도 검거', '강간 발생', '강간 검거', '절도 발생',
#        '절도 검거', '폭력 발생', '폭력 검거'],
#       dtype='object')

# %%
crime.index
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %%
# 정량적 데이터의 기초통계분석
crime.describe()
# Out:
#            살인 발생      살인 검거      강도 발생      강도 검거       강간 발생       강간 검거
# count  31.000000  31.000000  31.000000  31.000000   31.000000   31.000000
# mean    5.258065   4.935484   8.903226   8.161290  175.774194  131.967742
# std     3.605253   3.203493   4.935280   5.710206   85.580259   56.590037
# min     1.000000   0.000000   1.000000   1.000000   59.000000   46.000000
# 25%     3.000000   2.500000   6.000000   4.000000  103.500000   90.000000
# 50%     4.000000   4.000000   8.000000   7.000000  154.000000  124.000000
# 75%     7.500000   7.500000  13.000000  11.500000  251.000000  175.500000
# max    14.000000  12.000000  22.000000  26.000000  334.000000  247.000000

# %%
# 피벗 = 축

# %%
# pandas의 pivot_table

# %%
crime
# Out:
#      관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거
# 0    중부서      2      2      3      2    105     65  1,395    477  1,355  1,170
# 1    종로서      3      3      6      5    115     98  1,070    413  1,278  1,070
# 2   남대문서      1      0      6      4     65     46  1,153    382    869    794
# 3   서대문서      2      2      5      4    154    124  1,812    738  2,056  1,711
# 4    혜화서      3      2      5      4     96     63  1,114    424  1,015    861
# 5    용산서      5      5     14     14    194    173  1,557    587  2,050  1,704
# 6    성북서      2      2      2      1     86     71    953    409  1,194  1,015
# 7   동대문서      5      5     13     13    173    146  1,981    814  2,548  2,227
# 8    마포서      8      8     14     10    294    247  2,555    813  2,983  2,519
# 9   영등포서     14     12     22     20    295    183  2,964    978  3,572  2,961
# 10   성동서      4      4      9      8    126    119  1,607    597  1,612  1,395
# ...

# %%
crime_anal_raw = pd.read_csv('D:/python3/data/crime_in_Seoul_include_gu_name.csv', encoding='utf-8')
crime_anal_raw.head()
# Out:
#    Unnamed: 0   관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  \
# 0           0   중부서      2      2      3      2    105     65   1395    477
# 1           1   종로서      3      3      6      5    115     98   1070    413
# 2           2  남대문서      1      0      6      4     65     46   1153    382
# 3           3  서대문서      2      2      5      4    154    124   1812    738
# 4           4   혜화서      3      2      5      4     96     63   1114    424
#
#    폭력 발생  폭력 검거    구별
# 0   1355   1170    중구
# 1   1278   1070   종로구
# 2    869    794    중구
# 3   2056   1711  서대문구
# 4   1015    861   종로구

# %%
crime_anal_raw.shape
# Out:
# (31, 13)

# %%
crime_anal_raw
# Out:
#     Unnamed: 0   관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  \
# 0            0   중부서      2      2      3      2    105     65   1395    477
# 1            1   종로서      3      3      6      5    115     98   1070    413
# 2            2  남대문서      1      0      6      4     65     46   1153    382
# 3            3  서대문서      2      2      5      4    154    124   1812    738
# 4            4   혜화서      3      2      5      4     96     63   1114    424
# 5            5   용산서      5      5     14     14    194    173   1557    587
# 6            6   성북서      2      2      2      1     86     71    953    409
# 7            7  동대문서      5      5     13     13    173    146   1981    814
# 8            8   마포서      8      8     14     10    294    247   2555    813
# 9            9  영등포서     14     12     22     20    295    183   2964    978
# 10          10   성동서      4      4      9      8    126    119   1607    597
# ...

# %%
# 관서별에서 구별로 바꿔서 데이터를 정리
crime_anal_raw = pd.read_csv('D:/python3/data/crime_in_Seoul_include_gu_name.csv',
                             encoding='utf-8', index_col=0)
# 피벗테이블
crime_anal = pd.pivot_table(crime_anal_raw, index='구별', aggfunc=np.sum)
crime_anal.head()        # aggregation?_func 집합함수 - 동일한 구별끼리 합침(sum)
                             # pivot테이블을 만들면 object가 날라감....(관서명 ㅂㅂ)
# Out:
#      강간 검거  강간 발생  강도 검거  강도 발생  살인 검거  살인 발생  절도 검거  절도 발생  폭력 검거  폭력 발생
# 구별
# 강남구    349    449     18     21     10     13   1650   3850   3705   4284
# 강동구    123    156      8      6      3      4    789   2366   2248   2712
# 강북구    126    153     13     14      8      7    618   1434   2348   2649
# 관악구    221    320     14     12      8      9    827   2706   2642   3298
# 광진구    220    240     26     14      4      4   1277   3026   2180   2625

# %%
# # 검거율 (강간,강도,살인,절도,폭력)
for i in ['강간','강도','살인','절도','폭력']:
     crime_anal[i+' 검거율'] = crime_anal[i+' 검거'] / crime_anal[i+' 발생'] *100
crime_anal.head()
# Out:
#      강간 검거  강간 발생  강도 검거  강도 발생  살인 검거  살인 발생  절도 검거  절도 발생  폭력 검거  폭력 발생  \
# 구별
# 강남구    349    449     18     21     10     13   1650   3850   3705   4284
# 강동구    123    156      8      6      3      4    789   2366   2248   2712
# 강북구    126    153     13     14      8      7    618   1434   2348   2649
# 관악구    221    320     14     12      8      9    827   2706   2642   3298
# 광진구    220    240     26     14      4      4   1277   3026   2180   2625
#
#         강간 검거율      강도 검거율      살인 검거율     절도 검거율     폭력 검거율
# 구별
# 강남구  77.728285   85.714286   76.923077  42.857143  86.484594
# 강동구  78.846154  133.333333   75.000000  33.347422  82.890855
# 강북구  82.352941   92.857143  114.285714  43.096234  88.637222
# 관악구  69.062500  116.666667   88.888889  30.561715  80.109157
# 광진구  91.666667  185.714286  100.000000  42.200925  83.047619

# %% [markdown]
# ## pandas의 pivot_table

# %%
df = pd.read_excel("D:/python3/data/02. sales-funnel.xlsx")
df.head()
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
# 4          CPU         2  65000        won

# %%
pd.pivot_table(df, index=['Name'])  # 데이터, 기준(index) # 겹치는 이름(Name)은 자동으로 평균값이 나옴
# 숫자 value는 평균을 갖게 된다. -> 합계를 하려면 aggfunc=np.sum 해야함
# Out:
#                               Account   Price  Quantity
# Name
# Barton LLC                     740150   35000  1.000000
# Fritsch, Russel and Anderson   737550   35000  1.000000
# Herman LLC                     141962   65000  2.000000
# Jerde-Hilpert                  412290    5000  2.000000
# Kassulke, Ondricka and Metz    307599    7000  3.000000
# Keeling LLC                    688981  100000  5.000000
# Kiehn-Spinka                   146832   65000  2.000000
# Koepp Ltd                      729833   35000  2.000000
# Kulas Inc                      218895   25000  1.500000
# Purdy-Kunde                    163416   30000  1.000000
# Stokes LLC                     239344    7500  1.000000
# Trantow-Barrows                714466   15000  1.333333

# %%
pd.pivot_table(df, index=['Name', 'Rep', 'Manager'])
# Out:
#                                                           Account   Price  \
# Name                         Rep           Manager
# Barton LLC                   John Smith    Debra Henley    740150   35000
# Fritsch, Russel and Anderson Craig Booker  Debra Henley    737550   35000
# Herman LLC                   Cedric Moss   Fred Anderson   141962   65000
# Jerde-Hilpert                John Smith    Debra Henley    412290    5000
# Kassulke, Ondricka and Metz  Wendy Yule    Fred Anderson   307599    7000
# Keeling LLC                  Wendy Yule    Fred Anderson   688981  100000
# Kiehn-Spinka                 Daniel Hilton Debra Henley    146832   65000
# Koepp Ltd                    Wendy Yule    Fred Anderson   729833   35000
# Kulas Inc                    Daniel Hilton Debra Henley    218895   25000
# Purdy-Kunde                  Cedric Moss   Fred Anderson   163416   30000
# Stokes LLC                   Cedric Moss   Fred Anderson   239344    7500
# ...

# %%
# 특정 value만 표시
pd.pivot_table(df, index=['Manager', 'Rep'], values=['Price'])
# Out:
#                                     Price
# Manager       Rep
# Debra Henley  Craig Booker   20000.000000
#               Daniel Hilton  38333.333333
#               John Smith     20000.000000
# Fred Anderson Cedric Moss    27500.000000
#               Wendy Yule     44250.000000

# %%
pd.pivot_table(df, index=['Manager', 'Rep'], values=['Price'], aggfunc=np.sum)
# Out:
#                               Price
# Manager       Rep
# Debra Henley  Craig Booker    80000
#               Daniel Hilton  115000
#               John Smith      40000
# Fred Anderson Cedric Moss    110000
#               Wendy Yule     177000

# %%
pd.pivot_table(df, index=['Manager', 'Rep', 'Product'], values=['Price', 'Quantity'],
              aggfunc=[np.sum, np.mean], fill_value=0)  # 결측값 0으로 채움
# Out:
#                                             sum            mean
#                                           Price Quantity  Price Quantity
# Manager       Rep           Product
# Debra Henley  Craig Booker  CPU           65000        2  32500      1.0
#                             Maintenance    5000        2   5000      2.0
#                             Software      10000        1  10000      1.0
#               Daniel Hilton CPU          105000        4  52500      2.0
#                             Software      10000        1  10000      1.0
#               John Smith    CPU           35000        1  35000      1.0
#                             Maintenance    5000        2   5000      2.0
# Fred Anderson Cedric Moss   CPU           95000        3  47500      1.5
#                             Maintenance    5000        1   5000      1.0
#                             Software      10000        1  10000      1.0
# ...

# %%
crime_anal
# Out:
#       강간 검거  강간 발생  강도 검거  강도 발생  살인 검거  살인 발생  절도 검거  절도 발생  폭력 검거  폭력 발생  \
# 구별
# 강남구     349    449     18     21     10     13   1650   3850   3705   4284
# 강동구     123    156      8      6      3      4    789   2366   2248   2712
# 강북구     126    153     13     14      8      7    618   1434   2348   2649
# 관악구     221    320     14     12      8      9    827   2706   2642   3298
# 광진구     220    240     26     14      4      4   1277   3026   2180   2625
# 구로구     164    281     11     15      6      8    889   2335   2432   3007
# 금천구     122    151      6      6      4      3    888   1567   1776   2054
# 노원구     121    197      7      7     10     10    801   2193   2329   2723
# 도봉구     106    102     10      9      3      3    478   1063   1303   1487
# 동대문구    146    173     13     13      5      5    814   1981   2227   2548
# 동작구     139    285      5      9      5      5    661   1865   1587   1910
# ...

# %%
# 파생변수 : 5대 범죄에 검거율을 계산하여 각 컬럼에 대입
# ['강간','강도','살인','절도','폭력']
crime_anal['강간검거율'] = crime_anal['강간 검거'] / crime_anal['강간 발생'] *100
crime_anal['강도검거율'] = crime_anal['강도 검거'] / crime_anal['강도 발생'] *100
crime_anal['살인검거율'] = crime_anal['살인 검거'] / crime_anal['살인 발생'] *100
crime_anal['절도검거율'] = crime_anal['절도 검거'] / crime_anal['절도 발생'] *100
crime_anal['폭력검거율'] = crime_anal['폭력 검거'] / crime_anal['폭력 발생'] *100

# 불필요한 컬럼 제거
del crime_anal['강간 검거']
del crime_anal['강도 검거']
del crime_anal['살인 검거']
del crime_anal['절도 검거']
del crime_anal['폭력 검거']

crime_anal.head()
# Out:
#      강간 발생  강도 발생  살인 발생  절도 발생  폭력 발생     강간 검거율      강도 검거율      살인 검거율  \
# 구별
# 강남구    449     21     13   3850   4284  77.728285   85.714286   76.923077
# 강동구    156      6      4   2366   2712  78.846154  133.333333   75.000000
# 강북구    153     14      7   1434   2649  82.352941   92.857143  114.285714
# 관악구    320     12      9   2706   3298  69.062500  116.666667   88.888889
# 광진구    240     14      4   3026   2625  91.666667  185.714286  100.000000
#
#         절도 검거율     폭력 검거율      강간검거율       강도검거율       살인검거율      절도검거율  \
# 구별
# 강남구  42.857143  86.484594  77.728285   85.714286   76.923077  42.857143
# 강동구  33.347422  82.890855  78.846154  133.333333   75.000000  33.347422
# 강북구  43.096234  88.637222  82.352941   92.857143  114.285714  43.096234
# 관악구  30.561715  80.109157  69.062500  116.666667   88.888889  30.561715
# 광진구  42.200925  83.047619  91.666667  185.714286  100.000000  42.200925
#
#          폭력검거율
# 구별
# 강남구  86.484594
# 강동구  82.890855
# 강북구  88.637222
# ...

# %%
col_list = ['강간검거율','강도검거율','살인검거율','절도검거율','폭력검거율']

for c in col_list:
    crime_anal.loc[crime_anal[c]>100, c] = 100  # 스켈링? / 최대 100으로 맞춰줌
    
crime_anal.head()
# Out:
#      강간 발생  강도 발생  살인 발생  절도 발생  폭력 발생     강간 검거율      강도 검거율      살인 검거율  \
# 구별
# 강남구    449     21     13   3850   4284  77.728285   85.714286   76.923077
# 강동구    156      6      4   2366   2712  78.846154  133.333333   75.000000
# 강북구    153     14      7   1434   2649  82.352941   92.857143  114.285714
# 관악구    320     12      9   2706   3298  69.062500  116.666667   88.888889
# 광진구    240     14      4   3026   2625  91.666667  185.714286  100.000000
#
#         절도 검거율     폭력 검거율      강간검거율       강도검거율       살인검거율      절도검거율  \
# 구별
# 강남구  42.857143  86.484594  77.728285   85.714286   76.923077  42.857143
# 강동구  33.347422  82.890855  78.846154  100.000000   75.000000  33.347422
# 강북구  43.096234  88.637222  82.352941   92.857143  100.000000  43.096234
# 관악구  30.561715  80.109157  69.062500  100.000000   88.888889  30.561715
# 광진구  42.200925  83.047619  91.666667  100.000000  100.000000  42.200925
#
#          폭력검거율
# 구별
# 강남구  86.484594
# 강동구  82.890855
# 강북구  88.637222
# ...

# %%
# 피처(특성, 컬럼)명 변경
crime_anal.rename(columns={'강간 발생':'강간',   # rename은 사전형태로 담음
                          '강도 발생':'강도',
                          '살인 발생':'살인',
                          '절도 발생':'절도',
                          '폭력 발생':'폭력'}, inplace=True) 
crime_anal.head()
# Out:
#       강간  강도  살인    절도    폭력     강간 검거율      강도 검거율      살인 검거율     절도 검거율  \
# 구별
# 강남구  449  21  13  3850  4284  77.728285   85.714286   76.923077  42.857143
# 강동구  156   6   4  2366  2712  78.846154  133.333333   75.000000  33.347422
# 강북구  153  14   7  1434  2649  82.352941   92.857143  114.285714  43.096234
# 관악구  320  12   9  2706  3298  69.062500  116.666667   88.888889  30.561715
# 광진구  240  14   4  3026  2625  91.666667  185.714286  100.000000  42.200925
#
#         폭력 검거율      강간검거율       강도검거율       살인검거율      절도검거율      폭력검거율
# 구별
# 강남구  86.484594  77.728285   85.714286   76.923077  42.857143  86.484594
# 강동구  82.890855  78.846154  100.000000   75.000000  33.347422  82.890855
# 강북구  88.637222  82.352941   92.857143  100.000000  43.096234  88.637222
# 관악구  80.109157  69.062500  100.000000   88.888889  30.561715  80.109157
# 광진구  83.047619  91.666667  100.000000  100.000000  42.200925  83.047619

# %% [markdown]
# ### 정규화(Normalization)
# - 데이터의 최소0, 최대1 사이의 비율값을 대체

# %% [raw]
# 정규화 Xnew = X - Xmin / Xmax - Xmin : 숫자 데이터의 정규화 공식
#
# from sklearn.preprocessing import MinMaxScaler        # 사이키런 # 정규화
# scalar = MinMaxScaler()
# df[:] = scaler.fit_transform(df[:])         # 모든 값이 0~1 사이로 결정됨

# %%
# from sklearn.preprocessing import MinMaxScaler
from sklearn import preprocessing

# 정규화 대상 컬럼만 추출
col = ['강간', '강도', '살인', '절도', '폭력']

x = crime_anal[col].values
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x.astype(float))

crime_anal_norm = pd.DataFrame(x_scaled, columns = col, index=crime_anal.index)

col2 = ['강간검거율', '강도검거율', '살인검거율', '절도검거율', '폭력검거율']

crime_anal_norm[col2] = crime_anal[col2]   # 복사
crime_anal_norm.head()                      # 정규화 해야 시각화할때 보기 좋음,,?
# Out:
#            강간        강도        살인        절도        폭력      강간검거율       강도검거율  \
# 구별
# 강남구  1.000000  0.941176  0.916667  0.953472  0.661386  77.728285   85.714286
# 강동구  0.155620  0.058824  0.166667  0.445775  0.289667  78.846154  100.000000
# 강북구  0.146974  0.529412  0.416667  0.126924  0.274769  82.352941   92.857143
# 관악구  0.628242  0.411765  0.583333  0.562094  0.428234  69.062500  100.000000
# 광진구  0.397695  0.529412  0.166667  0.671570  0.269094  91.666667  100.000000
#
#           살인검거율      절도검거율      폭력검거율
# 구별
# 강남구   76.923077  42.857143  86.484594
# 강동구   75.000000  33.347422  82.890855
# 강북구  100.000000  43.096234  88.637222
# 관악구   88.888889  30.561715  80.109157
# 광진구  100.000000  42.200925  83.047619

# %%
# 서울시 CCTV 현황 분석의 결과 파일을 불러와,
# '구 별'로 가져온 자료 중 인구수와 소계를 범죄 현황 데이터에 포함시키는 작업
result_CCTV = pd.read_csv("D:/python3/data/CCTV_result.csv",
                         encoding='utf-8', index_col = '구 별')
result_CCTV
# Out:
#         소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 구 별
# 강남구   2780  150.619195  570500.0  565550.0   4950.0  63167.0  0.867660
# 강동구    773  166.490765  453233.0  449019.0   4214.0  54622.0  0.929765
# 강북구    748  125.203252  330192.0  326686.0   3506.0  54813.0  1.061806
# 강서구    884  134.793814  603772.0  597248.0   6524.0  72548.0  1.080540
# 관악구   1496  149.290780  525515.0  507203.0  18312.0  68082.0  3.484582
# 광진구    707   53.228621  372164.0  357211.0  14953.0  42214.0  4.017852
# 구로구   1561   64.973730  447874.0  416487.0  31387.0  56833.0  7.007998
# 금천구   1015  100.000000  255082.0  236353.0  18729.0  32970.0  7.342345
# 노원구   1265  188.929889  569384.0  565565.0   3819.0  71941.0  0.670725
# 도봉구    485  246.638655  348646.0  346629.0   2017.0  51312.0  0.578524
# 동대문구  1294   74.766355  369496.0  354079.0  15417.0  54173.0  4.172440
# 동작구   1091  139.338235  412520.0  400456.0  12064.0  56013.0  2.924464
# ...

# %%
crime_anal_norm[['인구수', 'CCTV']] = result_CCTV[['인구수', '소계']]
crime_anal_norm.head()
# Out:
#            강간        강도        살인        절도        폭력      강간검거율       강도검거율  \
# 구별
# 강남구  1.000000  0.941176  0.916667  0.953472  0.661386  77.728285   85.714286
# 강동구  0.155620  0.058824  0.166667  0.445775  0.289667  78.846154  100.000000
# 강북구  0.146974  0.529412  0.416667  0.126924  0.274769  82.352941   92.857143
# 관악구  0.628242  0.411765  0.583333  0.562094  0.428234  69.062500  100.000000
# 광진구  0.397695  0.529412  0.166667  0.671570  0.269094  91.666667  100.000000
#
#           살인검거율      절도검거율      폭력검거율       인구수  CCTV
# 구별
# 강남구   76.923077  42.857143  86.484594  570500.0  2780
# 강동구   75.000000  33.347422  82.890855  453233.0   773
# 강북구  100.000000  43.096234  88.637222  330192.0   748
# 관악구   88.888889  30.561715  80.109157  525515.0  1496
# 광진구  100.000000  42.200925  83.047619  372164.0   707

# %%
# 각 범죄의 발생건수를 범죄라는 이름으로 합하는 작업
col = ['강간', '강도', '살인', '절도', '폭력']
crime_anal_norm['범죄'] = np.sum(crime_anal_norm[col], axis=1)
crime_anal_norm.head()
# Out:
#            강간        강도        살인        절도        폭력      강간검거율       강도검거율  \
# 구별
# 강남구  1.000000  0.941176  0.916667  0.953472  0.661386  77.728285   85.714286
# 강동구  0.155620  0.058824  0.166667  0.445775  0.289667  78.846154  100.000000
# 강북구  0.146974  0.529412  0.416667  0.126924  0.274769  82.352941   92.857143
# 관악구  0.628242  0.411765  0.583333  0.562094  0.428234  69.062500  100.000000
# 광진구  0.397695  0.529412  0.166667  0.671570  0.269094  91.666667  100.000000
#
#           살인검거율      절도검거율      폭력검거율       인구수  CCTV        범죄
# 구별
# 강남구   76.923077  42.857143  86.484594  570500.0  2780  4.472701
# 강동구   75.000000  33.347422  82.890855  453233.0   773  1.116551
# 강북구  100.000000  43.096234  88.637222  330192.0   748  1.494746
# 관악구   88.888889  30.561715  80.109157  525515.0  1496  2.613667
# 광진구  100.000000  42.200925  83.047619  372164.0   707  2.034438

# %%
# 각 범죄의 검거율을 검거라는 이름으로 합하는 작업
col2 = ['강간검거율', '강도검거율', '살인검거율', '절도검거율', '폭력검거율']
crime_anal_norm['검거'] = np.sum(crime_anal_norm[col2], axis=1)
crime_anal_norm.head()
# Out:
#            강간        강도        살인        절도        폭력      강간검거율       강도검거율  \
# 구별
# 강남구  1.000000  0.941176  0.916667  0.953472  0.661386  77.728285   85.714286
# 강동구  0.155620  0.058824  0.166667  0.445775  0.289667  78.846154  100.000000
# 강북구  0.146974  0.529412  0.416667  0.126924  0.274769  82.352941   92.857143
# 관악구  0.628242  0.411765  0.583333  0.562094  0.428234  69.062500  100.000000
# 광진구  0.397695  0.529412  0.166667  0.671570  0.269094  91.666667  100.000000
#
#           살인검거율      절도검거율      폭력검거율       인구수  CCTV        범죄          검거
# 구별
# 강남구   76.923077  42.857143  86.484594  570500.0  2780  4.472701  369.707384
# 강동구   75.000000  33.347422  82.890855  453233.0   773  1.116551  370.084431
# 강북구  100.000000  43.096234  88.637222  330192.0   748  1.494746  406.943540
# 관악구   88.888889  30.561715  80.109157  525515.0  1496  2.613667  368.622261
# 광진구  100.000000  42.200925  83.047619  372164.0   707  2.034438  416.915211

# %% [markdown]
# ## Seaborn 라이브러리를 활용한 시각화
# - pip install seaborn

# %%
import seaborn as sns  # matplotlib을 미리 가져와야 함

# %%
# 데이터 생성
x = np.linspace(0, 14, 100)    # linespace : 선형 구간에서 지정 구간의 수만큼 분할
y1 = np.sin(x)
y2 = 2 * np.sin(x+0.5)         # 숫자는 큰 의미 없음..
y3 = 3 * np.sin(x+1.0)
y4 = 4 * np.sin(x+1.5)

plt.figure(figsize=(10, 6))
plt.plot(x, y1, x, y2, x, y3, x, y4)
plt.show()

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(10, 6))
plt.plot(x, y1, x, y2, x, y3, x, y4)
plt.show()

# %%
# seaborn 데이터셋을 불러오는 작업
tips = sns.load_dataset('tips')
tips.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
# 요일별 매출현황
plt.figure(figsize=(8, 6))
# boxplot : 상자수염그래프, 이상치를 찾아내는 효과를 가지고 있는 시각화도구
sns.boxplot(x='day', y='total_bill', data=tips)
plt.show()

# %% [raw]
# 최솟값, 1사분위수, 중위수(2사분위수), 3사분위수, 최댓값
# 박스안에 선 - 중앙값
# 3사분위수에서 1사분위수 뺀값 -> 범위,,,
# 범위 넘어간것 -> 이상치
# 이상치가 많으면 신뢰성이 떨어짐
# 이상치, 결측치 많으면 정확도가 떨어짐

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='day', y='total_bill', hue='smoker', data=tips)
plt.show()

# %% [raw]
# 흡연자가 결재금액이 더 높다.. 팁도 더 줄까? -> 상관관계 분석

# %%
# 상관분석 : 매출금액과 팁
# 선형회귀분석
sns.set(style='darkgrid')
sns.lmplot(x='total_bill', y='tip', data=tips)
plt.show()

# %%
sns.set(style='darkgrid')
sns.lmplot(x='total_bill', y='tip', hue='smoker', data=tips)
plt.show()

# %%
# 연도와 월별 항공기 승객 수를 기록한 데이터
# flights -> seaborn에 내장되어있는 자료
flights = sns.load_dataset('flights')
flights.head(10)
# Out:
#    year      month  passengers
# 0  1949    January         112
# 1  1949   February         118
# 2  1949      March         132
# 3  1949      April         129
# 4  1949        May         121
# 5  1949       June         135
# 6  1949       July         148
# 7  1949     August         148
# 8  1949  September         136
# 9  1949    October         119

# %%
flights = flights.pivot('month', 'year', 'passengers')
flights.head(10)
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
#
# year       1960
# month
# January     417
# February    391
# March       419
# April       461
# May         472
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(flights, annot=True, fmt='d')  # 히트맵 안에 박스로,, fmt= format, d= decimal
plt.show()                       # 히트맵은 상관계수에 따라 색이 매겨짐

# %% [markdown]
# ## 범죄현황 분석 시각화

# %%
# os별로 한글처리하는 작업
import platform
from matplotlib import font_manager, rc

if platform.system() == 'Darwin':
    rc('font', family = 'AppleGothic')
elif platform.system() == 'Windows':
    path = "C:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print("Unknown system.....")

# %%
# 산점도 행렬 : 여러 개의 컬럼(피쳐)을 이용하여 산점도 그래프를 그리는 것
# 상관관계를 분석할 때 많이 쓰임  ex.히트맵, 산점도,,,,  산점도 행렬 [페어플롯(함수)]
# 강도, 살인, 폭력 간의 상관관계를 분석하는 그래프
sns.pairplot(crime_anal_norm,              # 데이터셋
             vars=['강도','살인','폭력'],  # 관측값
             kind='reg', size=3)           # regression
plt.show()

# %%
sns.pairplot(crime_anal_norm,
        x_vars=['인구수','CCTV'], y_vars=['살인','강도'],
        kind='reg', height=3)
plt.show()

# %%
sns.pairplot(crime_anal_norm,
        x_vars=['인구수','CCTV'], y_vars=['살인검거율','폭력검거율'],
        kind='reg', height=3)
plt.show()

# %%
crime_anal_norm.head(10)
# Out:
#             강간        강도        살인        절도        폭력       강간검거율  \
# 구별
# 강남구   1.000000  0.941176  0.916667  0.953472  0.661386   77.728285
# 강동구   0.155620  0.058824  0.166667  0.445775  0.289667   78.846154
# 강북구   0.146974  0.529412  0.416667  0.126924  0.274769   82.352941
# 관악구   0.628242  0.411765  0.583333  0.562094  0.428234   69.062500
# 광진구   0.397695  0.529412  0.166667  0.671570  0.269094   91.666667
# 구로구   0.515850  0.588235  0.500000  0.435169  0.359423   58.362989
# 금천구   0.141210  0.058824  0.083333  0.172426  0.134074   80.794702
# 노원구   0.273775  0.117647  0.666667  0.386589  0.292268   61.421320
# 도봉구   0.000000  0.235294  0.083333  0.000000  0.000000  100.000000
# 동대문구  0.204611  0.470588  0.250000  0.314061  0.250887   84.393064
#
#            강도검거율       살인검거율      절도검거율      폭력검거율       인구수  CCTV        범죄  \
# 구별
# 강남구    85.714286   76.923077  42.857143  86.484594  570500.0  2780  4.472701
# ...

# %%
# 검거율의 합을 검거라는 파생변수로 생성했다.
# 검거의 최댓값을 100으로 한정하고, 그에 따른 정규화 작업을 수행
# '검거'의 최댓값을 계산
tmp_max = crime_anal_norm['검거'].max()
crime_anal_norm['검거'] = crime_anal_norm['검거']/tmp_max*100
crime_anal_norm.head(10)

# %%
crime_anal_norm_sort = crime_anal_norm.sort_values(by='검거', ascending=False)
crime_anal_norm_sort.head()       # by - 키값, ascending=False 내림차순
# Out:
#             강간        강도        살인        절도        폭력       강간검거율  강도검거율  \
# 구별
# 도봉구   0.000000  0.235294  0.083333  0.000000  0.000000  100.000000  100.0
# 금천구   0.141210  0.058824  0.083333  0.172426  0.134074   80.794702  100.0
# 광진구   0.397695  0.529412  0.166667  0.671570  0.269094   91.666667  100.0
# 동대문구  0.204611  0.470588  0.250000  0.314061  0.250887   84.393064  100.0
# 용산구   0.265130  0.529412  0.250000  0.169004  0.133128   89.175258  100.0
#
#       살인검거율      절도검거율      폭력검거율       인구수  CCTV        범죄          검거
# 구별
# 도봉구   100.0  44.967074  87.626093  348646.0   485  0.318627  100.000000
# 금천구   100.0  56.668794  86.465433  255082.0  1015  0.589867   97.997139
# 광진구   100.0  42.200925  83.047619  372164.0   707  2.034438   96.375820
# 동대문구  100.0  41.090358  87.401884  369496.0  1294  1.490147   95.444250
# 용산구   100.0  37.700706  83.121951  244203.0  1624  1.346674   94.776790

# %%
# 시각화 대상
col = ['강간검거율','강도검거율','살인검거율','절도검거율','폭력검거율']
# 범죄 검거 비율을 시각화하는 작업
plt.figure(figsize=(10,10))
sns.heatmap(crime_anal_norm_sort[col],  # 데이터셋
            annot=True,     # annot 맵 셀에 값의 표시여부
            fmt='f',        # 셀에 표시되는 값의 포멧형식(타입) = 'f'(float)
            linewidth=.5)   # 라인두께
plt.title('범죄 검거 비율(정규화된 검거의 합으로 정렬)')
plt.show()
# 오른쪽에 Cmap(colormap)이 기본적으로 표시됨 (그라데이션 되어있는 막대기,,)

# %% [markdown]
# ### 지도시각화(Folium-포리움)
#  - 파이썬에서 제공하는 라이브러리로, 지도를 다루는 대표적인 라이브러리
#  - 네이버,구글 등 api제공받아서 ,, 시각화,,,,할수도 있음 (지오코딩 등)
#  - 외부 : pip install folium  (외부라이브러리 가져오기 - 파이프 인스톨)
#  - 로딩 : import folium as g (가져온 라이브러리 로딩하기)
#  - 위도와 경도를 이용해서 시각화
# 1. Map객체
#    Map(location=[위도, 경도], zoom_start=10)  # zoom_start 처음 지도 나왔을때 배율

# %%
import folium as g  # 해당 모듈이 없음..ㅠㅠ
# Anaconda PowerShall Prompt - 관리자권한실행
# pip install folium
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-55-cabe28a5662f> in <module>
# ----> 1 import folium as g
#
# ModuleNotFoundError: No module named 'folium'

# %%
import folium as g

# %%
# Map객체를 사용해서 location 옵션에 위도, 경도를 설정
# 연돈 : 33.25909, 126.40727
g_map = g.Map(location=[33.25909, 126.40727], zoom_start=18)  # location이라는 글자는 생략가능
g_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
# marker(표식)
marker = g.Marker([33.25909, 126.40727], popup='연돈',
                  icon=g.Icon(color='blue'))
marker.add_to(g_map)
g_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
# 범위를 원형태로 지정하는 작업, CircleMarker
marker2 = g.CircleMarker([33.25909, 126.40727],
                        radius=100,           # 원의 크기(반지름)
                        color='skyblue',      # 원의 선 색깔
                        fill_color='skyblue', # 원 내부 색깔
                        popup='연돈')
marker2.add_to(g_map)
g_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
# 지도의 스타일 : tiles = ''
# OpenStreetMap, Stamen Terrain, Stamen Toner, Stamen Watercolor
map_osm = g.Map(location=[45.5236, -122.6750])
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
map_osm = g.Map(location=[45.5236, -122.6750], tiles='OpenStreetMap')
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
map_osm = g.Map(location=[45.5236, -122.6750], tiles='Stamen Terrain')
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
map_osm = g.Map(location=[45.5236, -122.6750], tiles='Stamen Toner')
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
map_osm = g.Map(location=[45.5236, -122.6750], tiles='Stamen Watercolor')
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ## 서울시 범죄 현황 분석 지도시각화

# %%
import json

# %%
# 서울시 구 별 데이터
geo_path="D:/python3/data/skorea_municipalities_geo_simple.json"
# json 파일 로딩
geo_str = json.load(open(geo_path, encoding='utf-8'))

# %%
map = g.Map(location=[37.5502, 126.982],  # 서울시 위도와 경도
           zoom_start=11, tiles='Stamen Toner')

map.choropleth(geo_data=geo_str,    # 추가할 데이터
              data=crime_anal_norm['살인'],
              columns=[crime_anal_norm.index, crime_anal_norm['살인']],
              fill_color='PuRd',    # Purple ~ Red
              key_on='feature.id')  # 피쳐아이디-> id('구' 이름)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
